# %% [markdown]
# # Class 3 : trainer (smiritica shadukhan) Student (MD.Redoy Sarder)

# %% [markdown]
# # Python Dictionary

# %%
d1 = {'name':'Redoy',
      'Roll':'101',
      'Batch':'ES PML 2303',
      'Class No': 4,
      'SI': [1,2,3,4],
      'set': {'a', 'b', 'c'},
      'dict':(5,6,7,8),
      'txt':'i, am, a, student.'
     }

d1
# Out:
# {'name': 'Redoy',
#  'Roll': '101',
#  'Batch': 'ES PML 2303',
#  'Class No': 4,
#  'SI': [1, 2, 3, 4],
#  'set': {'a', 'b', 'c'},
#  'dict': (5, 6, 7, 8),
#  'txt': 'i, am, a, student.'}

# %%
d1['name']
# Out:
# 'Redoy'

# %%
d1['Batch']
# Out:
# 'ES PML 2303'

# %%
d1['SI']
# Out:
# [1, 2, 3, 4]

# %%
d1['SI'][2]
# Out:
# 3

# %%
d1['txt']
# Out:
# 'i, am, a, student.'

# %%
d1['txt'][11]
# Out:
# 't'

# %%
type(d1)
# Out:
# dict

# %%
len(d1)
# Out:
# 8

# %% [markdown]
# # 4.1.1 clear()

# %%
d1
# Out:
# {'name': 'Redoy',
#  'Roll': '101',
#  'Batch': 'ES PML 2303',
#  'Class No': 4,
#  'SI': [1, 2, 3, 4],
#  'set': {'a', 'b', 'c'},
#  'dict': (5, 6, 7, 8),
#  'txt': 'i, am, a, student.'}

# %%
d1.clear()

# %%
d1
# Out:
# {}

# %% [markdown]
# # 4.1.2 copy()

# %%
d2 = {'Engineer' : 'প্রকৌশলী',
      'Methods'  : 'পদ্ধতি',
      'Database' : 'তথ্যশালা',
      'Algorithm': 'গাণিতিক পরিভাষা, সমাধানপদ্ধতি'}

d2
# Out:
# {'Engineer': 'প্রকৌশলী',
#  'Methods': 'পদ্ধতি',
#  'Database': 'তথ্যশালা',
#  'Algorithm': 'গাণিতিক পরিভাষা, সমাধানপদ্ধতি'}

# %%
d2
# Out:
# {'Engineer': 'প্রকৌশলী',
#  'Methods': 'পদ্ধতি',
#  'Database': 'তথ্যশালা',
#  'Algorithm': 'গাণিতিক পরিভাষা, সমাধানপদ্ধতি'}

# %%
x = d2.copy()

# %%
x
# Out:
# {'Engineer': 'প্রকৌশলী',
#  'Methods': 'পদ্ধতি',
#  'Database': 'তথ্যশালা',
#  'Algorithm': 'গাণিতিক পরিভাষা, সমাধানপদ্ধতি'}

# %% [markdown]
# # 4.1.3 fromkeys()

# %%
a = ('k1', 'k2', 'k3')
b = 'value'

# %%
c = dict.fromkeys(a,b) # The fromkeys() method creates a dictionary by concatenating keys and values

# %%
c
# Out:
# {'k1': 'value', 'k2': 'value', 'k3': 'value'}

# %%
a1 = 'k'
b1 = ('v1', 'v2', 'v3', 'v4')

# %%
c = dict.fromkeys(a1,b1)

# %%
c
# Out:
# {'k': ('v1', 'v2', 'v3', 'v4')}

# %%
type(c)
# Out:
# dict

# %%
len(c)
# Out:
# 1

# %% [markdown]
# # 4.1.4 get()

# %%
d2
# Out:
# {'Engineer': 'প্রকৌশলী',
#  'Methods': 'পদ্ধতি',
#  'Database': 'তথ্যশালা',
#  'Algorithm': 'গাণিতিক পরিভাষা, সমাধানপদ্ধতি'}

# %%
d2.get("Methods")
# Out:
# 'পদ্ধতি'

# %%
d2["Methods"]
# Out:
# 'পদ্ধতি'

# %%
d2
# Out:
# {'Engineer': 'প্রকৌশলী',
#  'Methods': 'পদ্ধতি',
#  'Database': 'তথ্যশালা',
#  'Algorithm': 'গাণিতিক পরিভাষা, সমাধানপদ্ধতি'}

# %%
e1 = d2.get("Name", "নাম")

# %%
e1
# Out:
# 'নাম'

# %% [markdown]
# # 4.1.5 items()

# %%
d2
# Out:
# {'Engineer': 'প্রকৌশলী',
#  'Methods': 'পদ্ধতি',
#  'Database': 'তথ্যশালা',
#  'Algorithm': 'গাণিতিক পরিভাষা, সমাধানপদ্ধতি'}

# %%
x1 = d2.items()

# %%
x1
# Out:
# dict_items([('Engineer', 'প্রকৌশলী'), ('Methods', 'পদ্ধতি'), ('Database', 'তথ্যশালা'), ('Algorithm', 'গাণিতিক পরিভাষা, সমাধানপদ্ধতি')])

# %% [markdown]
# # 4.1.6 keys()

# %%
d2
# Out:
# {'Engineer': 'প্রকৌশলী',
#  'Methods': 'পদ্ধতি',
#  'Database': 'তথ্যশালা',
#  'Algorithm': 'গাণিতিক পরিভাষা, সমাধানপদ্ধতি'}

# %%
d2.keys()
# Out:
# dict_keys(['Engineer', 'Methods', 'Database', 'Algorithm'])

# %% [markdown]
# # 4.1.7 values()

# %%
d2
# Out:
# {'Engineer': 'প্রকৌশলী',
#  'Methods': 'পদ্ধতি',
#  'Database': 'তথ্যশালা',
#  'Algorithm': 'গাণিতিক পরিভাষা, সমাধানপদ্ধতি'}

# %%
d2.values()
# Out:
# dict_values(['প্রকৌশলী', 'পদ্ধতি', 'তথ্যশালা', 'গাণিতিক পরিভাষা, সমাধানপদ্ধতি'])

# %% [markdown]
# # 4.1.8 pop()

# %%
s1 = {'w1': 'm1', 'w2': 'm2', 'w3':'m3','w4':'m4'}

# %%
s1
# Out:
# {'w1': 'm1', 'w2': 'm2', 'w3': 'm3', 'w4': 'm4'}

# %%
s1.pop('w1') # any item remove pop() method

s1
# Out:
# {'w2': 'm2', 'w3': 'm3', 'w4': 'm4'}

# %% [markdown]
# # 4.1.9 popitem()

# %%
s1.popitem() # last items remove  popitem() method
# Out:
# ('w4', 'm4')

# %%
s1
# Out:
# {'w2': 'm2', 'w3': 'm3'}

# %% [markdown]
# # 4.2.0 setdefault()

# %%
price = {'book' : '300 BDT',
         'pen'  : '25 BDT',  # setdefault() method used
         'khata': '120 BDT'
     }

price
# Out:
# {'book': '300 BDT', 'pen': '25 BDT', 'khata': '120 BDT'}

# %%
f1 = price.setdefault('pen','55 BDT') # setdefault() method used

# %%
f1
# Out:
# '25 BDT'

# %% [markdown]
# # 4.2.1 update()

# %%
price
# Out:
# {'book': '300 BDT', 'pen': '25 BDT', 'khata': '120 BDT'}

# %%
price.update({'pen':'75 BDT'})

# %%
price
# Out:
# {'book': '300 BDT', 'pen': '75 BDT', 'khata': '120 BDT'}

# %%
price['pen'] = "100 BDT"

price
# Out:
# {'book': '300 BDT', 'pen': '100 BDT', 'khata': '120 BDT'}

# %% [markdown]
# # 4.2.2 del

# %%
price
# Out:
# {'book': '300 BDT', 'pen': '100 BDT', 'khata': '120 BDT'}

# %%
del price['pen'], price['book'] # delete single value using multipal items

# %%
price
# Out:
# {'khata': '120 BDT'}

# %%
del price # delete  all dictionary

# %%
price # dictionary deleteed
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 price
#
# NameError: name 'price' is not defined

# %% [markdown]
# # Nested Dectionary

# %%
my_family = {"child1":

             {'gc1':{'name':'n1','old':5},
              'gc2':{'name':'n1','old':8},
              'gc3':{'name':'n1','old':12}
             },

             "child2":

             {'gc1':{'name':'n1','old':15},
              'gc2':{'name':'n1','old':20},
              'gc3':{'name':'n1','old':25}
             },

             "child3":

             {'gc1':{'name':'n1','old':30},
              'gc2':{'name':'n1','old':35},
              'gc3':{'name':'n1','old':40}
             }
            }

# %%
my_family["child3"]["gc3"]["old"]

# %%
myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}

# %%
myfamily['child3']['year']
