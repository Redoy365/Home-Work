# %% [markdown]
# # Class 2 : trainer (smiritica shadukhan) Student (MD.Redoy Sarder)

# %% [markdown]
# # Class 2 Ordering,Duplicate,Mutable,Set,Tuple

# %%
# Data Structure

# %%
# list []
# set {}
# tuple ()
# dict {}

# %% [markdown]
# # Geting Start { List } 📄

# %%
list1 = [2,2,4,7,9,3.8,'new']

# %%
list1
# Out:
# [2, 2, 4, 7, 9, 3.8, 'new']

# %%
type(list1)
# Out:
# list

# %%
len(list1)
# Out:
# 7

# %%
list1[2:]
# Out:
# [4, 7, 9, 3.8, 'new']

# %%
list1[:2]
# Out:
# [2, 2]

# %%
list1[2:5]
# Out:
# [4, 7, 9]

# %%
list1
# Out:
# [2, 2, 4, 7, 9, 3.8, 'new']

# %%
list1[::2]
# Out:
# [2, 4, 9, 'new']

# %%
list1[::-1]
# Out:
# ['new', 3.8, 9, 7, 4, 2, 2]

# %%
list1[::-2]
# Out:
# ['new', 9, 4, 2]

# %%
list1[::2]
# Out:
# [2, 4, 9, 'new']

# %%
list1[::-2]
# Out:
# ['new', 9, 4, 2]

# %%
list1
# Out:
# [2, 2, 4, 7, 9, 3.8, 'new']

# %%
list1[1:3] + list1[4:6]
# Out:
# [2, 4, 9, 3.8]

# %%
list1[:]
# Out:
# [2, 2, 4, 7, 9, 3.8, 'new']

# %%
list1[::]
# Out:
# [2, 2, 4, 7, 9, 3.8, 'new']

# %%
list1[1:6:2]
# Out:
# [2, 7, 3.8]

# %%
# Negative indexing

# %%
list1
# Out:
# [2, 2, 4, 7, 9, 3.8, 'new']

# %%
list1[-1]
# Out:
# 'new'

# %%
list1[-4]
# Out:
# 7

# %%
list1[-4:]
# Out:
# [7, 9, 3.8, 'new']

# %%
list1[:-4]
# Out:
# [2, 2, 4]

# %%
list1[3:]
# Out:
# [7, 9, 3.8, 'new']

# %%
list1
# Out:
# [2, 2, 4, 7, 9, 3.8, 'new']

# %%
list1[-3:]
# Out:
# [9, 3.8, 'new']

# %%
list1
# Out:
# [2, 2, 4, 7, 9, 3.8, 'new']

# %%
list1[3:]
# Out:
# [7, 9, 3.8, 'new']

# %%
list1[:5]
# Out:
# [2, 2, 4, 7, 9]

# %%
# add (single/multipal) value
# append, insert, extend
# remove (single/multiple) value
# remove,del,pop

# %%
# append(), insert(), extend(), remove(), pop(), del(), clear(), sort(), copy(), count(), index(), reverse(), min(), max()

# %%
#append =========================Start
list_1 = [1,2,3,4]

# %%
list_1.append(5)
list_1
# Out:
# [1, 2, 3, 4, 5]

# %%
list_2 = ['a','b','c','d']
list_2
# Out:
# ['a', 'b', 'c', 'd']

# %%
list_2.append('e')
list_2
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
# insert ======================= Start

# %%
list_1
# Out:
# [1, 2, 3, 4, 5]

# %%
list_1.insert(1,55) # single value pass

# %%
list_1
# Out:
# [1, 55, 2, 3, 4, 5]

# %%
# extend =================== start

# %%
list_1
# Out:
# [1, 2, 3, 4, 5]

# %%
list_2
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
list_1.extend(list_2) # append (list to list)

# %%
list_1
# Out:
# [1, 2, 3, 4, 5, 'a', 'b', 'c', 'd', 'e']

# %%
# remove ======================= start

# %%
list_1.remove(1) # remove single value (value name)

# %%
list_1
# Out:
# [2, 3, 4, 5, 'a', 'b', 'c', 'd', 'e']

# %%
list_a = ['a','b','c']

# %%
list_a.pop(1) # remove single value (index number)
# Out:
# 'b'

# %%
list_a
# Out:
# ['a', 'c']

# %%
# del ========================= start

# %%
list_b = ['d', 'e', 'f']

# %%
del list_b

# %%
list_b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 list_b
#
# NameError: name 'list_b' is not defined

# %%
# clear =====================start

# %%
my_list = [2,4,6]
my_list
# Out:
# [2, 4, 6]

# %%
my_list.clear()
my_list
# Out:
# []

# %%
# short ==================== start

# %%
new_list = [5,3,7,1,9]

# %%
new_list
# Out:
# [5, 3, 7, 1, 9]

# %%
new_list.sort()
new_list
# Out:
# [1, 3, 5, 7, 9]

# %%
x = new_list.copy()

# %%
x
# Out:
# [1, 3, 5, 7, 9]

# %%
# count ================== start

# %%
new = [1,2,3,1,1,4,5,3]

# %%
new.count(1) # listname.count(count number)
# Out:
# 3

# %%
# index ===================start

# %%
new
# Out:
# [1, 2, 3, 1, 1, 4, 5, 3]

# %%
new.index(4)
# Out:
# 5

# %%
# revers ================= start

# %%
new1 = [1,2,3,4]
new1
# Out:
# [1, 2, 3, 4]

# %%
new1.reverse()

# %%
new1
# Out:
# [4, 3, 2, 1]

# %%
new1[::-1]
# Out:
# [1, 2, 3, 4]

# %%
max(new1)
# Out:
# 4

# %%
min(new1)
# Out:
# 1

# %% [markdown]
# # Get Start  { set } 🗄

# %%
# python set methode
# add(),
# clear(),
# copy(),
# difference(),
# difference_update()
# discard()
# union()
# intersection()
# intersection_update()
# isdisjoint()
# issubset()
# issuperset()
# pop()
# remove()
# symmetric_difference()
# symmetric_difference_update()
# update()

# %%
set1 = {1,2,3,4}

# %%
set1
# Out:
# {1, 2, 3, 4}

# %%
set1.add(5) # list append
set1
# Out:
# {1, 2, 3, 4, 5}

# %%
set1.clear()
set1
# Out:
# set()

# %%
type(set1)
# Out:
# set

# %%
del set1

# %%
set1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 set1
#
# NameError: name 'set1' is not defined

# %%
set2 = {1,2,3,5}

# %%
set2.copy()
# Out:
# {1, 2, 3, 5}

# %%
set2
# Out:
# {1, 2, 3, 5}

# %%
set3 = {3,4,5}
set3
# Out:
# {3, 4, 5}

# %%
set2.difference(set3)
# Out:
# {1, 2}

# %%
set2.difference_update(set3) # buzena

# %%
s1 = {1,2,3}
s1
# Out:
# {1, 2, 3}

# %%
s1.discard(2)
s1
# Out:
# {1, 3}

# %%
a1 = {1,2,3}
b1 = {2,3,4}

# %%
a1.union(b1)
# Out:
# {1, 2, 3, 4}

# %%
a1.intersection(b1)
# Out:
# {2, 3}

# %%
x = {"apple", "banana", "cherry"}
x
# Out:
# {'apple', 'banana', 'cherry'}

# %%
y = {"google", "microsoft", "apple"}
y
# Out:
# {'apple', 'google', 'microsoft'}

# %%
# intersection ======================== start

# %%
z = x.intersection(y)
z
# Out:
# {'apple'}

# %%
# intersection_update ======================= start

# %%
x.intersection_update(y)

# %%
x
# Out:
# {'apple'}

# %%
f = {1,2,3,4}
f
# Out:
# {1, 2, 3, 4}

# %%
g = {1,4,8,9}
g
# Out:
# {1, 4, 8, 9}

# %%
f.difference(g)
# Out:
# {2, 3}

# %%
f
# Out:
# {1, 2, 3, 4}

# %%
g
# Out:
# {1, 4, 8, 9}

# %%
f.discard(2)
f
# Out:
# {1, 3, 4}

# %%
h = [1,2,3]
h.remove(2)
h
# Out:
# [1, 3]

# %%
f
# Out:
# {1, 3, 4}

# %%
g
# Out:
# {1, 4, 8, 9}

# %%
f.symmetric_difference(g)
# Out:
# {1, 3, 4}

# %%
f.symmetric_difference_update(g)
f
# Out:
# {1, 3, 4}

# %%
f
# Out:
# {1, 3, 4}

# %%
g
# Out:
# {1, 4, 8, 9}

# %%
f.update(g)
f
# Out:
# {1, 3, 4, 8, 9}

# %%
#=========== list vs set ============
# list              set
# -----            ------
# extend <________> update
# add <___________< append
# discard <_______< remove

# %% [markdown]
# # Tuple

# %%
t5u = (2,1,2,3,4,2,9)
t5u
# Out:
# (2, 1, 2, 3, 4, 2, 9)

# %%
type(t5u)
# Out:
# tuple

# %%
t5u.count(2)
# Out:
# 3

# %%
t5u.index(9)
# Out:
# 6
