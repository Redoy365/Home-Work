# %% [markdown]
# # Class 5 : trainer (smiritica shadukhan) Student (MD.Redoy Sarder)

# %% [markdown]
# # Python Condition

# %%
# if condition

# %%
x = 5

y = 6

if x<y:
    print('x lessthen y')
if y<x:
    print('y lessthen x')
# Out:
# x lessthen y

# %%
# elif condition

# %%
x1 = 10
y1 = 20

if x<y:
    print('x less then y')
elif x>y:
    print('y greater then y')
# Out:
# x less then y

# %%
# else condition

# %%
x2 = 7
y2 = 8

if x2 > y2:
    print('x2 grater then y2')
else:
    print('y2 grather then x2')
# Out:
# y2 grather then x2

# %%
resturent1 = 'R1'
    student_age > 21
    student_covit = 2
resturent2 = 'R2'
    student_age >18
    student_covit = 2
# Out:
#   Cell In[7], line 2
#     student_age > 21
#     ^
# IndentationError: unexpected indent

# %%
student_age = 29
student_covit = 1

# %%
if student_covit == 2:
    if student_age > 21:
        print('student is allowed in Resturent 1 Resturent 2')
    elif student_age > 18:
        print('student allowed in Resturent 2')
    else:
        print('student is not allowed in Resturent 1 and Resturent 2')
else:
    print('student vaccine not sufficient')

# %%
student_mark > 90 excellent
80-89 very good
70-79 good
60-69 average
50-59 normal
40-49 very normal
33-39 poor
33 < student_mark faild

# %%
student_mark = 95

if student_mark > 90:
    print('excellent')

elif student_mark >= 80 and student_mark <=89:
    print('very good')

elif student_mark >= 70 and student_mark <=79:
    print('good')

elif student_mark >= 60 and student_mark <=69:
    print('average')

elif student_mark >= 50 and student_mark <=59:
    print('normal')

elif student_mark >= 40 and student_mark <=49:
    print('very normal')

elif student_mark >= 33 and student_mark <=39:
    print('poor')

elif student_mark <= 33:
    print('faild')

# %%
list1 = [1,6,8,4,6]

list1[1] = list1[1]**2

list1

# %%
for i in list1:
    print(i**2, end=' ')

# %%
for i in list1[::2]:
    print(i+10)

# %%
list1

# %%
for i in list1:
    print(list1.index(i))

# %%
list2 = [1,6,8,4,6]

# %%
for i in list2:
    ele = list2.index(i)
    print('list1[',ele,']=',i,'**2 = ',i**2)
    list2[ele] = i**2

# %%
list3 = [1,6,8,4,6]
list3
# Out:
# [1, 6, 8, 4, 6]

# %%
list4=[]
for i in list3:
    list4.append(i**2)
    print(list4)
# Out:
# [1]
# [1, 36]
# [1, 36, 64]
# [1, 36, 64, 16]
# [1, 36, 64, 16, 36]
